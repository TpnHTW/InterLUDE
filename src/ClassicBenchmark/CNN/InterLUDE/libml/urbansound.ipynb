# %%
import soundata

dataset = soundata.initialize('urbansound8k')
dataset.download()  # download the dataset
dataset.validate()  # validate that all the expected files are there

example_clip = dataset.choice_clip()  # choose a random example clip
print(example_clip)  # see the available data
# Out:
# INFO: Downloading ['all', 'index']. Index is being stored in /Users/philipnartschik/InterLUDE/.venv/lib/python3.10/site-packages/soundata/datasets/indexes, and the rest of files in /Users/philipnartschik/sound_datasets/urbansound8k
# INFO: [all] downloading UrbanSound8K.tar.gz
#   1%|          | 38.8M/5.61G [04:16<10:28:12, 159kB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import soundata
#       3 dataset = soundata.initialize('urbansound8k')
# ----> 4 dataset.download()  # download the dataset
#       5 dataset.validate()  # validate that all the expected files are there
#       7 example_clip = dataset.choice_clip()  # choose a random example clip
#
# File ~/InterLUDE/.venv/lib/python3.10/site-packages/soundata/core.py:328, in Dataset.download(self, partial_download, force_overwrite, cleanup)
#     311 def download(self, partial_download=None, force_overwrite=False, cleanup=False):
#     312     """Download data to `save_dir` and optionally print a message.
#     313
#     314     Args:
#    (...)
#     326
#     327     """
# --> 328     download_utils.downloader(
#     329         self.data_home,
#     330         remotes=self.remotes,
#     331         index=self._index_data,
#     332         partial_download=partial_download,
#     333         info_message=self._download_info,
#     334         force_overwrite=force_overwrite,
#     335         cleanup=cleanup,
#     336     )
#
# File ~/InterLUDE/.venv/lib/python3.10/site-packages/soundata/download_utils.py:141, in downloader(save_dir, remotes, index, partial_download, info_message, force_overwrite, cleanup)
#     139     download_zip_file(remotes[k], save_dir, force_overwrite, cleanup)
#     140 elif ".gz" in extension or ".tar" in extension or ".bz2" in extension:
# --> 141     download_tar_file(remotes[k], save_dir, force_overwrite, cleanup)
#     142 elif ".7z" in extension:
#     143     download_7z_file(remotes[k], save_dir, force_overwrite, cleanup)
#
# File ~/InterLUDE/.venv/lib/python3.10/site-packages/soundata/download_utils.py:386, in download_tar_file(tar_remote, save_dir, force_overwrite, cleanup)
#     376 def download_tar_file(tar_remote, save_dir, force_overwrite, cleanup):
#     377     """Download and untar a tar file.
#     378
#     379     Args:
#    (...)
#     384
#     385     """
# --> 386     tar_download_path = download_from_remote(tar_remote, save_dir, force_overwrite)
#     387     untar(tar_download_path, cleanup=cleanup)
#
# File ~/InterLUDE/.venv/lib/python3.10/site-packages/soundata/download_utils.py:252, in download_from_remote(remote, save_dir, force_overwrite)
#     248 with DownloadProgressBar(
#     249     unit="B", unit_scale=True, unit_divisor=1024, miniters=1
#     250 ) as t:
#     251     try:
# --> 252         urllib.request.urlretrieve(
#     253             remote.url,
#     254             filename=download_path,
#     255             reporthook=t.update_to,
#     256             data=None,
#     257         )
#     258     except Exception as exc:
#     259         error_msg = """
#     260                     soundata failed to download the dataset from {}!
#     261                     Please try again in a few minutes.
#    (...)
#     266             remote.url
#     267         )
#
# File /usr/local/Cellar/python@3.10/3.10.16/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:270, in urlretrieve(url, filename, reporthook, data)
#     267     reporthook(blocknum, bs, size)
#     269 while True:
# --> 270     block = fp.read(bs)
#     271     if not block:
#     272         break
#
# File /usr/local/Cellar/python@3.10/3.10.16/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File /usr/local/Cellar/python@3.10/3.10.16/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File /usr/local/Cellar/python@3.10/3.10.16/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/Cellar/python@3.10/3.10.16/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:
